# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=300)
lngs = np.random.uniform(low=-180.000, high=180.000, size=300)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the Citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 201

# %%
print(cities)
# Out:
# ['longyearbyen', 'mezhevoy', 'aasiaat', 'albany', 'kamenka', 'ribeira grande', 'topeka', 'illoqqortoormiut', 'zhigansk', 'parabel', 'busselton', 'rikitea', 'ushuaia', 'sentyabrskiy', 'dikson', 'chumikan', 'cape town', 'omsukchan', 'carutapera', 'yellowknife', 'kavieng', 'butaritari', 'tezu', 'kuressaare', 'te anau', 'nguiu', 'lakes entrance', 'barrow', 'karaul', 'sol-iletsk', 'kapaa', 'lompoc', 'teeli', 'punta arenas', 'sungairaya', 'umzimvubu', 'ilulissat', 'hermanus', 'salamiyah', 'grand-santi', 'xiongzhou', 'puerto baquerizo moreno', 'port alfred', 'encinitas', 'terdal', 'esperance', 'naze', 'berezovyy', 'chuy', 'san pedro', 'mataura', 'kilcormac', 'panama city', 'lagoa', 'mys shmidta', 'maceio', 'port elizabeth', 'olafsvik', 'lebu', 'aripuana', 'salalah', 'east london', 'lasa', 'madera', 'bonavista', 'adrar', 'vaini', 'tasiilaq', 'samusu', 'pombas', 'bolungarvik', 'misratah', 'jerome', 'saskylakh', 'nizhneyansk', 'jamestown', 'saint george', 'saint-pierre', 'flinders', 'kodiak', 'tuktoyaktuk', 'bethel', 'bredasdorp', 'san luis', 'khatanga', 'ambilobe', 'anaconda', 'chokurdakh', 'avarua', 'puerto ayora', 'ancud', 'bluff', 'sorland', 'lavrentiya', 'luderitz', 'georgetown', 'saurimo', 'mar del plata', 'avera', 'amderma', 'batemans bay', 'markova', 'belushya guba', 'atuona', 'pochutla', 'banda aceh', 'griffith', 'carnarvon', 'attawapiskat', 'taoudenni', 'hilo', 'dingle', 'lodja', 'vardo', 'castro', 'bambous virieux', 'raymond', 'baruun-urt', 'kurumkan', 'jalu', 'valle de allende', 'karratha', 'sioux lookout', 'denpasar', 'klaksvik', 'tulum', 'vawkavysk', 'hornepayne', 'rio brilhante', 'isangel', 'pevek', 'ushtobe', 'pyaozerskiy', 'san joaquin', 'jardim', 'hobart', 'saint-philippe', 'ixtapa', 'green valley', 'alice springs', 'marfino', 'neuquen', 'masuda', 'quatre cocos', 'nuevitas', 'new norfolk', 'caravelas', 'nome', 'provideniya', 'faanui', 'banjar', 'wanning', 'quelimane', 'miri', 'narsaq', 'nikolskoye', 'arraial do cabo', 'northport', 'yining', 'thompson', 'airai', 'hithadhoo', 'grand river south east', 'kruisfontein', 'sakaiminato', 'krasnoselkup', 'alyangula', 'qaanaaq', 'skibbereen', 'waiouru', 'tessalit', 'mouila', 'constitucion', 'port hardy', 'tocopilla', 'ruwi', 'fortuna', 'karla', 'albert lea', 'saint-augustin', 'kaitangata', 'clyde river', 'marawi', 'cabinda', 'coahuayana', 'mahebourg', 'hamilton', 'cabedelo', 'angoche', 'bandarbeyla', 'emerald', 'ugoofaaru', 'plouzane', 'lamu', 'souillac', 'mujiayingzi', 'ashtian', 'touros', 'holetown', 'capitan bado', 'steinbach']

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | mezhevoy
# Processing Record 3 of Set 1 | aasiaat
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | kamenka
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | topeka
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | zhigansk
# Processing Record 10 of Set 1 | parabel
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | chumikan
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | omsukchan
# Processing Record 19 of Set 1 | carutapera
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | tezu
# Processing Record 24 of Set 1 | kuressaare
# Processing Record 25 of Set 1 | te anau
# Processing Record 26 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 1 | lakes entrance
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 1 | sol-iletsk
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | teeli
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | sungairaya
# Processing Record 36 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | salamiyah
# Processing Record 40 of Set 1 | grand-santi
# Processing Record 41 of Set 1 | xiongzhou
# Processing Record 42 of Set 1 | puerto baquerizo moreno
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | encinitas
# Processing Record 45 of Set 1 | terdal
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | berezovyy
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | san pedro
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | kilcormac
# Processing Record 3 of Set 2 | panama city
# Processing Record 4 of Set 2 | lagoa
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | maceio
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | olafsvik
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | aripuana
# Processing Record 11 of Set 2 | salalah
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | lasa
# Processing Record 14 of Set 2 | madera
# Processing Record 15 of Set 2 | bonavista
# Processing Record 16 of Set 2 | adrar
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 2 | pombas
# Processing Record 21 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 2 | misratah
# Processing Record 23 of Set 2 | jerome
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | saint-pierre
# Processing Record 29 of Set 2 | flinders
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | san luis
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | ambilobe
# Processing Record 37 of Set 2 | anaconda
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | ancud
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | sorland
# Processing Record 44 of Set 2 | lavrentiya
# Processing Record 45 of Set 2 | luderitz
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | saurimo
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | batemans bay
# Processing Record 2 of Set 3 | markova
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | atuona
# Processing Record 5 of Set 3 | pochutla
# Processing Record 6 of Set 3 | banda aceh
# Processing Record 7 of Set 3 | griffith
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | taoudenni
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | dingle
# Processing Record 13 of Set 3 | lodja
# Processing Record 14 of Set 3 | vardo
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | raymond
# Processing Record 18 of Set 3 | baruun-urt
# Processing Record 19 of Set 3 | kurumkan
# Processing Record 20 of Set 3 | jalu
# Processing Record 21 of Set 3 | valle de allende
# Processing Record 22 of Set 3 | karratha
# Processing Record 23 of Set 3 | sioux lookout
# Processing Record 24 of Set 3 | denpasar
# Processing Record 25 of Set 3 | klaksvik
# Processing Record 26 of Set 3 | tulum
# Processing Record 27 of Set 3 | vawkavysk
# Processing Record 28 of Set 3 | hornepayne
# Processing Record 29 of Set 3 | rio brilhante
# Processing Record 30 of Set 3 | isangel
# Processing Record 31 of Set 3 | pevek
# Processing Record 32 of Set 3 | ushtobe
# Processing Record 33 of Set 3 | pyaozerskiy
# Processing Record 34 of Set 3 | san joaquin
# Processing Record 35 of Set 3 | jardim
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | ixtapa
# Processing Record 39 of Set 3 | green valley
# Processing Record 40 of Set 3 | alice springs
# Processing Record 41 of Set 3 | marfino
# Processing Record 42 of Set 3 | neuquen
# Processing Record 43 of Set 3 | masuda
# Processing Record 44 of Set 3 | quatre cocos
# Processing Record 45 of Set 3 | nuevitas
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | caravelas
# Processing Record 48 of Set 3 | nome
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | banjar
# Processing Record 2 of Set 4 | wanning
# Processing Record 3 of Set 4 | quelimane
# Processing Record 4 of Set 4 | miri
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | arraial do cabo
# Processing Record 8 of Set 4 | northport
# Processing Record 9 of Set 4 | yining
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | sakaiminato
# Processing Record 16 of Set 4 | krasnoselkup
# Processing Record 17 of Set 4 | alyangula
# Processing Record 18 of Set 4 | qaanaaq
# Processing Record 19 of Set 4 | skibbereen
# Processing Record 20 of Set 4 | waiouru
# Processing Record 21 of Set 4 | tessalit
# Processing Record 22 of Set 4 | mouila
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | port hardy
# Processing Record 25 of Set 4 | tocopilla
# Processing Record 26 of Set 4 | ruwi
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | karla
# Processing Record 29 of Set 4 | albert lea
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | clyde river
# Processing Record 33 of Set 4 | marawi
# Processing Record 34 of Set 4 | cabinda
# Processing Record 35 of Set 4 | coahuayana
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | cabedelo
# Processing Record 39 of Set 4 | angoche
# Processing Record 40 of Set 4 | bandarbeyla
# Processing Record 41 of Set 4 | emerald
# Processing Record 42 of Set 4 | ugoofaaru
# Processing Record 43 of Set 4 | plouzane
# Processing Record 44 of Set 4 | lamu
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | mujiayingzi
# Processing Record 47 of Set 4 | ashtian
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | holetown
# Processing Record 50 of Set 4 | capitan bado
# Processing Record 1 of Set 5 | steinbach
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("cities.csv",index_label = "City_ID")
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Longyearbyen  78.2186  15.6401      6.64        66           0        2.30
# 1      Mezhevoy  55.1711  58.7814     28.76        88         100        2.30
# 2       Aasiaat  68.7098 -52.8699      6.87       100          93        5.61
# 3        Albany  42.6001 -73.9662     39.67        42          97        1.99
# 4       Kamenka  51.3223  42.7678     36.41        99         100        1.79
#
#   Country                 Date
# 0      SJ  2022-03-31 03:40:50
# 1      RU  2022-03-31 03:44:24
# 2      GL  2022-03-31 03:44:25
# 3      US  2022-03-31 03:44:25
# 4      RU  2022-03-31 03:44:25

# %%
city_data_df = pd.read_csv("cities.csv")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Longyearbyen  78.2186   15.6401      6.64        66           0
# 1        Mezhevoy  55.1711   58.7814     28.76        88         100
# 2         Aasiaat  68.7098  -52.8699      6.87       100          93
# 3          Albany  42.6001  -73.9662     39.67        42          97
# 4         Kamenka  51.3223   42.7678     36.41        99         100
# 5  Ribeira Grande  38.5167  -28.7000     60.96        91         100
# 6          Topeka  39.0483  -95.6780     39.58        79         100
# 7        Zhigansk  66.7697  123.3711      1.78        75          91
# 8         Parabel  58.6978   81.4825     34.56        98         100
# 9       Busselton -33.6500  115.3333     80.76        49          29
#
#    Wind Speed Country                 Date
# 0        2.30      SJ  2022-03-31 03:40:50
# 1        2.30      RU  2022-03-31 03:44:24
# 2        5.61      GL  2022-03-31 03:44:25
# 3        1.99      US  2022-03-31 03:44:25
# 4        1.79      RU  2022-03-31 03:44:25
# 5        5.99      PT  2022-03-31 03:44:26
# 6       19.57      US  2022-03-31 03:40:41
# 7        3.38      RU  2022-03-31 03:44:28
# 8       20.24      RU  2022-03-31 03:44:28
# 9       11.54      AU  2022-03-31 03:44:29

# %%
new_column_order = ["City", "Cloudiness", "Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df[new_column_order].head(10)
# Out:
#              City  Cloudiness Country                 Date  Humidity      Lat  \
# 0    Longyearbyen           0      SJ  2022-03-31 03:40:50        66  78.2186
# 1        Mezhevoy         100      RU  2022-03-31 03:44:24        88  55.1711
# 2         Aasiaat          93      GL  2022-03-31 03:44:25       100  68.7098
# 3          Albany          97      US  2022-03-31 03:44:25        42  42.6001
# 4         Kamenka         100      RU  2022-03-31 03:44:25        99  51.3223
# 5  Ribeira Grande         100      PT  2022-03-31 03:44:26        91  38.5167
# 6          Topeka         100      US  2022-03-31 03:40:41        79  39.0483
# 7        Zhigansk          91      RU  2022-03-31 03:44:28        75  66.7697
# 8         Parabel         100      RU  2022-03-31 03:44:28        98  58.6978
# 9       Busselton          29      AU  2022-03-31 03:44:29        49 -33.6500
#
#         Lng  Max Temp  Wind Speed
# 0   15.6401      6.64        2.30
# 1   58.7814     28.76        2.30
# 2  -52.8699      6.87        5.61
# 3  -73.9662     39.67        1.99
# 4   42.7678     36.41        1.79
# 5  -28.7000     60.96        5.99
# 6  -95.6780     39.58       19.57
# 7  123.3711      1.78        3.38
# 8   81.4825     34.56       20.24
# 9  115.3333     80.76       11.54

# %%
# Create the output file (CSV).
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#Fonts and stuff
ifont = {'fontname':'Impact'}
hfont = {'fontname':'Helvetica'}
cfont = {'fontname':'Cambria'}


# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"), **ifont, fontsize=20)
plt.ylabel("Max Temperature (F)", **cfont, fontsize=15)
plt.xlabel("Latitude", **cfont, fontsize=15)
plt.grid(True)

# Save the figure.
plt.savefig("weather_data_Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#Fonts and stuff
ifont = {'fontname':'Impact'}
hfont = {'fontname':'Helvetica'}
cfont = {'fontname':'Cambria'}

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"), **ifont, fontsize=20)
plt.ylabel("Humidity (%)", **cfont, fontsize=15)
plt.xlabel("Latitude", **cfont, fontsize=15)
plt.grid(True)
# Save the figure.
plt.savefig("weather_data_Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#Fonts and stuff
ifont = {'fontname':'Impact'}
hfont = {'fontname':'Helvetica'}
cfont = {'fontname':'Cambria'}

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%)"+ time.strftime("%x"), **ifont, fontsize=20)
plt.ylabel("Cloudiness (%)", **cfont, fontsize=15)
plt.xlabel("Latitude", **cfont, fontsize=15)
plt.grid(True)
# Save the figure.
plt.savefig("weather_data_Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. windspeed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

#Fonts and stuff
ifont = {'fontname':'Impact'}
hfont = {'fontname':'Helvetica'}
cfont = {'fontname':'Cambria'}

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Windspeed (MPH)"+ time.strftime("%x"), **ifont, fontsize=20)
plt.ylabel("Windspeed (MPH)", **cfont, fontsize=15)
plt.xlabel("Latitude", **cfont, fontsize=15)
plt.grid(True)
# Save the figure.
plt.savefig("weather_data_Fig4.png")
# Show plot.
plt.show()

# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
temps = [18.2, 29.5, 35.9, 50.1, 58.6, 69.9 ]
daylight = [7.6, 9.2, 12.2, 13.4, 13.9, 14.2]

# %%
plt.scatter(daylight,temps)
plt.xlabel('hours of daylight')
plt.ylabel('av m temp')
plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City  Cloudiness Country                 Date  Humidity      Lat  \
# 0  Longyearbyen           0      SJ  2022-03-31 03:40:50        66  78.2186
# 1      Mezhevoy         100      RU  2022-03-31 03:44:24        88  55.1711
# 2       Aasiaat          93      GL  2022-03-31 03:44:25       100  68.7098
# 3        Albany          97      US  2022-03-31 03:44:25        42  42.6001
# 4       Kamenka         100      RU  2022-03-31 03:44:25        99  51.3223
#
#        Lng  Max Temp  Wind Speed
# 0  15.6401      6.64        2.30
# 1  58.7814     28.76        2.30
# 2 -52.8699      6.87        5.61
# 3 -73.9662     39.67        1.99
# 4  42.7678     36.41        1.79

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                     Chumikan
# Cloudiness                     73
# Country                        RU
# Date          2022-03-31 03:44:31
# Humidity                       54
# Lat                       54.7183
# Lng                       135.315
# Max Temp                    29.64
# Wind Speed                   7.38
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 183     True
# 184    False
# 185     True
# 186    False
# 187     True
# Name: Lat, Length: 188, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#              City  Cloudiness Country                 Date  Humidity      Lat  \
# 0    Longyearbyen           0      SJ  2022-03-31 03:40:50        66  78.2186
# 1        Mezhevoy         100      RU  2022-03-31 03:44:24        88  55.1711
# 2         Aasiaat          93      GL  2022-03-31 03:44:25       100  68.7098
# 3          Albany          97      US  2022-03-31 03:44:25        42  42.6001
# 4         Kamenka         100      RU  2022-03-31 03:44:25        99  51.3223
# ..            ...         ...     ...                  ...       ...      ...
# 179      Plouzane          75      FR  2022-03-31 03:48:57        93  48.3833
# 182   Mujiayingzi          61      CN  2022-03-31 03:48:58        22  42.1167
# 183       Ashtian          77      IR  2022-03-31 03:48:58        23  34.5217
# 185      Holetown          98      BB  2022-03-31 03:48:59        73  13.1867
# 187     Steinbach          20      DE  2022-03-31 03:50:00        75  50.1667
#
#           Lng  Max Temp  Wind Speed
# 0     15.6401      6.64        2.30
# 1     58.7814     28.76        2.30
# 2    -52.8699      6.87        5.61
# 3    -73.9662     39.67        1.99
# 4     42.7678     36.41        1.79
# ..        ...       ...         ...
# 179   -4.6167     46.72        6.91
# 182  118.7833     38.34       21.25
# 183   50.0019     36.27        2.10
# 185  -59.6381     77.56       18.37
# 187    8.5667     43.18        9.22
#
# [115 rows x 9 columns]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
gmaps.configure(api_key = g_key)

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("cities.csv")
city_data_df.head()
# Out:
#    City_ID          City  Cloudiness Country                 Date  Humidity  \
# 0        0  Longyearbyen           0      SJ  2022-03-31 03:40:50        66
# 1        1      Mezhevoy         100      RU  2022-03-31 03:44:24        88
# 2        2       Aasiaat          93      GL  2022-03-31 03:44:25       100
# 3        3        Albany          97      US  2022-03-31 03:44:25        42
# 4        4       Kamenka         100      RU  2022-03-31 03:44:25        99
#
#        Lat      Lng  Max Temp  Wind Speed
# 0  78.2186  15.6401      6.64        2.30
# 1  55.1711  58.7814     28.76        2.30
# 2  68.7098 -52.8699      6.87        5.61
# 3  42.6001 -73.9662     39.67        1.99
# 4  51.3223  42.7678     36.41        1.79

# %%
#get data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Cloudiness      int64
# Country        object
# Date           object
# Humidity        int64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
